# %% [markdown]
# ## **INSTALL DEPENDENCIES**

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 914.6/914.6 kB 12.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# # **DATASET**

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="3mmPC6JGbUmPueeJfMpX")
project = rf.workspace("joseph-nelson").project("plantdoc")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %% [markdown]
# # **YOLOV8 TRAINING**

# %%
from ultralytics import YOLO

# !yolo task=detect mode=train model=yolov8s.pt data=/content/PlantDoc-1/data.yaml epochs=30 imgsz=416
# Out:
# ...
# 100% 21.5M/21.5M [00:00<00:00, 217MB/s]
# Ultralytics 8.3.69 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# # **TESTING**

# %%
from ultralytics import YOLO
# !yolo task=detect mode=predict model=/content/drive/MyDrive/best.pt conf=0.25 source=/content/PlantDoc-1/test/images/sept4disease-019_jpg.rf.7d5a1ac7d63b933fb38cb6ab2aa22f38.jpg
# Out:
# Ultralytics 8.3.69 🚀 Python-3.11.11 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# YOLO11n summary (fused): 238 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
#
# image 1/1 /content/PlantDoc-1/test/images/sept4disease-019_jpg.rf.7d5a1ac7d63b933fb38cb6ab2aa22f38.jpg: 640x640 1 Aerial_Tank_Images - v2 2023-06-07 3-07pm, 214.4ms
# Speed: 7.2ms preprocess, 214.4ms inference, 22.6ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from ultralytics import YOLO
# !yolo task=detect mode=predict model=/content/drive/MyDrive/best.pt conf=0.25 source=/content/PlantDoc-1/test/images/powdery-mildew-sphaerotheca-fuliginea-infection-on-pumpkin-leaves-ajdkkx_jpg.rf.334ac0524ef19f67cf7d9790967bc65a.jpg
# Out:
# Ultralytics 8.3.69 🚀 Python-3.11.11 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# YOLO11n summary (fused): 238 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
#
# image 1/1 /content/PlantDoc-1/test/images/powdery-mildew-sphaerotheca-fuliginea-infection-on-pumpkin-leaves-ajdkkx_jpg.rf.334ac0524ef19f67cf7d9790967bc65a.jpg: 640x640 1 Aerial_Tank_Images - v2 2023-06-07 3-07pm, 188.4ms
# Speed: 8.4ms preprocess, 188.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict4
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from google.colab import files
dataset = files.upload()
# Out:
#      <input type="file" id="files-00a9450a-3f53-4897-91d2-0a0c77396033" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-00a9450a-3f53-4897-91d2-0a0c77396033">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip install ultralytics
from ultralytics import YOLO
# !yolo task=detect mode=predict model=/content/drive/MyDrive/best.pt conf=0.25 source=1.jpg
# !yolo task=detect mode=predict model=/content/drive/MyDrive/best.pt conf=0.25 source=2.jpg
# !yolo task=detect mode=predict model=/content/drive/MyDrive/best.pt conf=0.25 source=3.jpg
# !yolo task=detect mode=predict model=/content/drive/MyDrive/best.pt conf=0.25 source=4.jpg
# !yolo task=detect mode=predict model=/content/drive/MyDrive/best.pt conf=0.25 source=5.jpg
# !yolo task=detect mode=predict model=/content/drive/MyDrive/best.pt conf=0.25 source=6.jpg
# !yolo task=detect mode=predict model=/content/drive/MyDrive/best.pt conf=0.25 source=7.jpg
# !yolo task=detect mode=predict model=/content/drive/MyDrive/best.pt conf=0.25 source=8.jpg
# !yolo task=detect mode=predict model=/content/drive/MyDrive/best.pt conf=0.25 source=9.jpg
# !yolo task=detect mode=predict model=/content/drive/MyDrive/best.pt conf=0.25 source=10.jpg
# Out:
# ...
# Ultralytics 8.3.69 🚀 Python-3.11.11 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# YOLO11n summary (fused): 238 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
#
# image 1/1 /content/1.jpg: 640x640 1 Aerial_Tank_Images - v2 2023-06-07 3-07pm, 193.9ms
# Speed: 8.9ms preprocess, 193.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict5
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
# Ultralytics 8.3.69 🚀 Python-3.11.11 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# YOLO11n summary (fused): 238 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
#
# image 1/1 /content/2.jpg: 640x640 1 Aerial_Tank_Images - v2 2023-06-07 3-07pm, 185.9ms
# Speed: 7.4ms preprocess, 185.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict6
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
# Ultralytics 8.3.69 🚀 Python-3.11.11 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# ...
